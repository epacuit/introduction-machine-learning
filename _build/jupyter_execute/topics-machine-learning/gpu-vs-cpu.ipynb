# %% [markdown]
# (gpu-vs-cpu)=
# # GPU vs. CPU
#
# In this section, we will compare the performance of a CPU and a GPU when training a neural network on image data.
#
# The **CPU (Central Processing Unit)** is a general-purpose processor found in all computers. It is designed to efficiently handle a wide range of tasks, including sequential logic, control flow, and input/output operations. CPUs typically have a small number of powerful cores (e.g., 4 to 12) that are optimized for tasks requiring flexibility and complex decision-making.
#
# In contrast, the **GPU (Graphics Processing Unit)** is a specialized processor originally designed for rendering graphics. However, it turns out that the same features that make GPUs good at graphics — such as having hundreds or thousands of cores capable of doing the same operation in parallel — also make them ideal for tasks like training machine learning models.
#
# Machine learning, especially deep learning, involves intensive mathematical computations — particularly linear algebra operations like matrix multiplication. These operations are highly parallelizable, which means they can be split into many small parts and computed simultaneously. GPUs are built to excel at exactly this kind of computation, which is why they often outperform CPUs by a significant margin when training large models or working with large datasets.

# %%
# Set this to False to disable GPU (CPU-only)
USE_GPU = True
if not USE_GPU:
    # Disable GPU by uninstalling tensorflow-metal
    # !pip3 uninstall -y tensorflow-metal
else:
    # Make sure GPU plugin is installed
    # !pip3 install -U tensorflow-metal
    
print("⚠️ Please RESTART the kernel after this cell before continuing.")
# Out:
# Requirement already satisfied: tensorflow-metal in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: six>=1.15.0 in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow-metal) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# ⚠️ Please RESTART the kernel after this cell before continuing.

# %%
import tensorflow as tf

print("GPUs visible:", tf.config.list_physical_devices('GPU'))

# This prints every operation's device placement
tf.debugging.set_log_device_placement(True)
# Out:
# GPUs visible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape((-1, 28, 28, 1)).astype("float32") / 255
x_test = x_test.reshape((-1, 28, 28, 1)).astype("float32") / 255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Input(shape=(28, 28, 1)),
    # layers.Conv2D(128, 3, activation='relu'),
    # layers.MaxPooling2D(),
    # layers.Conv2D(64, 3, activation='relu'),
    # layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.230005: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2025-04-29 07:36:02.230024: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 96.00 GB
# 2025-04-29 07:36:02.230028: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 36.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745926562.230038 15702941 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1745926562.230056 15702941 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-04-29 07:36:02.237181: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.237191: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.237194: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.240176: I tensorflow/core/common_runtime/placer.cc:162] x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.240184: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.240187: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.282179: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.282192: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.282195: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.283871: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.283877: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.283881: I tensorflow/core/common_runtime/placer.cc:162] FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.283883: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.285837: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.285845: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.285847: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.290320: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.290332: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.290335: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.293250: I tensorflow/core/common_runtime/placer.cc:162] seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.293260: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.293264: I tensorflow/core/common_runtime/placer.cc:162] key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.293266: I tensorflow/core/common_runtime/placer.cc:162] counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.294808: I tensorflow/core/common_runtime/placer.cc:162] shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.294815: I tensorflow/core/common_runtime/placer.cc:162] key: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.294818: I tensorflow/core/common_runtime/placer.cc:162] counter: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.294820: I tensorflow/core/common_runtime/placer.cc:162] alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.294823: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.294826: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.299192: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.299201: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.299204: I tensorflow/core/common_runtime/placer.cc:162] Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.299206: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.302338: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.302346: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.302349: I tensorflow/core/common_runtime/placer.cc:162] Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.302351: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.305692: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.305698: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.305702: I tensorflow/core/common_runtime/placer.cc:162] AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.305704: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.309176: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.309182: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.309994: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.310004: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.310008: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.312597: I tensorflow/core/common_runtime/placer.cc:162] dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.312605: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.312609: I tensorflow/core/common_runtime/placer.cc:162] Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.312611: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.316144: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.316151: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.316877: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.316885: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.316889: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.331722: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.331734: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.332483: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.332490: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.332494: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.346283: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.346303: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.347292: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.347299: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.347302: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.359488: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.359503: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.360380: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.360389: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.360394: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.364549: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.364562: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.365266: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.365273: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.365276: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.370833: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.370843: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.371649: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.371654: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.371657: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.373498: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.373509: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.374060: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.374068: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.374071: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.378752: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.378763: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.381246: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.381257: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0

# %%
import time

start = time.time()
history = model.fit(x_train, y_train,
                    validation_split=0.1,
                    #batch_size=512,
                    batch_size=64,
                    epochs=5,
                    verbose=2)
end = time.time()

print(f"\nTraining time: {end - start:.2f} seconds")
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.387979: I tensorflow/core/common_runtime/placer.cc:162] start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.387986: I tensorflow/core/common_runtime/placer.cc:162] stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.387989: I tensorflow/core/common_runtime/placer.cc:162] step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.387992: I tensorflow/core/common_runtime/placer.cc:162] RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.387995: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.394211: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.394225: I tensorflow/core/common_runtime/placer.cc:162] MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.394228: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.395909: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.395917: I tensorflow/core/common_runtime/placer.cc:162] buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.395921: I tensorflow/core/common_runtime/placer.cc:162] PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.395924: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.401457: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.401466: I tensorflow/core/common_runtime/placer.cc:162] FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.401469: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/5
# Executing op AnonymousIteratorV3 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.444867: I tensorflow/core/common_runtime/placer.cc:162] components_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.444879: I tensorflow/core/common_runtime/placer.cc:162] components_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.444884: I tensorflow/core/common_runtime/placer.cc:162] TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.444887: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.455416: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.455430: I tensorflow/core/common_runtime/placer.cc:162] count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.455434: I tensorflow/core/common_runtime/placer.cc:162] RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.455436: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.457486: I tensorflow/core/common_runtime/placer.cc:162] input__datasets_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.457493: I tensorflow/core/common_runtime/placer.cc:162] input__datasets_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.457498: I tensorflow/core/common_runtime/placer.cc:162] ZipDataset: (ZipDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.457501: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02.461651: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-04-29 07:36:02
I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.511594: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.517824: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.517832: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.523501: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.523511: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.529326: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.529337: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.535934: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.535944: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.542986: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.542999: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.549337: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.549349: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.555137: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.555146: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.561008: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.561017: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.566692: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.566702: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.572148: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.572158: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.577893: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.577904: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.616539: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.616553: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.621673: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.621687: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:CPU:0
# key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# key: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# counter: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# components_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# components_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ZipDataset: (ZipDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# num__parallel__calls: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ParallelMapDatasetV2: (ParallelMapDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# AnonymousIteratorV3: (AnonymousIteratorV3): /job:localhost/replica:0/task:0/device:CPU:0
# dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# iterator: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# range: (Range): /job:localhost/replica:0/task:0/device:CPU:0
# RandomShuffle: (RandomShuffle): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# range/limit: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# ConcatenateDataset: (ConcatenateDataset): /job:localhost/replica:0/task:0/device:CPU:0
# NoOp: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Slice/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# args_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# args_2: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2_1: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Identity_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# identity_1_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2_1/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# values_0: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_1: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_2: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_3: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_4: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_5: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_6: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_7: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_8: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_9: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_10: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_11: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_12: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_13: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Pack: (P
# Executing op Pack in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_initialize_variables_912 in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.651589: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.651604: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.651607: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.653631: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.653639: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.653642: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.655368: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.655379: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.655382: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.657184: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.657196: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.657199: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.658577: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.658585: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.658588: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.660257: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.660263: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.660266: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.662105: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.662112: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.662116: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663979: I tensorflow/core/common_runtime/placer.cc:162] values_0: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663984: I tensorflow/core/common_runtime/placer.cc:162] values_1: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663987: I tensorflow/core/common_runtime/placer.cc:162] values_2: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663989: I tensorflow/core/common_runtime/placer.cc:162] values_3: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663992: I tensorflow/core/common_runtime/placer.cc:162] values_4: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663994: I tensorflow/core/common_runtime/placer.cc:162] values_5: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663996: I tensorflow/core/common_runtime/placer.cc:162] values_6: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.663998: I tensorflow/core/common_runtime/placer.cc:162] values_7: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664000: I tensorflow/core/common_runtime/placer.cc:162] values_8: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664002: I tensorflow/core/common_runtime/placer.cc:162] values_9: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664004: I tensorflow/core/common_runtime/placer.cc:162] values_10: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664006: I tensorflow/core/common_runtime/placer.cc:162] values_11: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664008: I tensorflow/core/common_runtime/placer.cc:162] values_12: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664010: I tensorflow/core/common_runtime/placer.cc:162] values_13: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664069: I tensorflow/core/common_runtime/placer.cc:162] Pack: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.664072: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678335: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678347: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678350: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_2_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678353: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_3_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678355: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_4_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678363: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_5_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678365: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_6_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678366: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_7_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678368: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_8_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678370: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_9_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678372: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_10_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678373: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_11_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678375: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_12_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678377: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_13_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678381: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_dense_kernel_momentum/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678390: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_dense_kernel_velocity/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678393: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678395: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_1: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678397: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_2: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678399: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_3: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678402: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_4: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678404: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_5: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678406: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_6: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678408: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_7: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678410: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_8: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678412: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_9: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678414: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_10: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678416: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_11: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678418: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_12: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678422: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_13: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678425: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_kernel_momentum/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678427: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_kernel_velocity/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678430: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_bias_momentum/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-04-29 07:36:02.678432: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_bias_velocity/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import time
#       3 start = time.time()
# ----> 4 history = model.fit(x_train, y_train,
#       5                     validation_split=0.1,
#       6                     #batch_size=512,
#       7                     batch_size=64,
#       8                     epochs=5,
#       9                     verbose=2)
#      10 end = time.time()
#      12 print(f"\nTraining time: {end - start:.2f} seconds")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Version 1 (with a larger CNN and batch size), for 5 Epochs:
# * Training on the CPU: 61.05 seconds
# * Training on the GPU: 15.04 seconds
#
# Version 2 (with a smaller CNN and batch size), for 5 Epochs:
# * Training on the CPU: 18.71 seconds
# * Training on the GPU: 57.40 seconds
#
# The conclusion is that the GPU is *not always* faster than the CPU.  There is a significant amount of overhead in transferring data to and from the GPU, and for smaller models or smaller batch sizes, this overhead can outweigh the benefits of parallel processing.

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()
