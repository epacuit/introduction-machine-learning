# %% [markdown]
# (gpu-vs-cpu)=
# # GPU vs. CPU
#
# In this section, we will compare the performance of a CPU and a GPU when training a neural network on image data.
#
# The **CPU (Central Processing Unit)** is a general-purpose processor found in all computers. It is designed to efficiently handle a wide range of tasks, including sequential logic, control flow, and input/output operations. CPUs typically have a small number of powerful cores (e.g., 4 to 12) that are optimized for tasks requiring flexibility and complex decision-making.
#
# In contrast, the **GPU (Graphics Processing Unit)** is a specialized processor originally designed for rendering graphics. However, it turns out that the same features that make GPUs good at graphics — such as having hundreds or thousands of cores capable of doing the same operation in parallel — also make them ideal for tasks like training machine learning models.
#
# Machine learning, especially deep learning, involves intensive mathematical computations — particularly linear algebra operations like matrix multiplication. These operations are highly parallelizable, which means they can be split into many small parts and computed simultaneously. GPUs are built to excel at exactly this kind of computation, which is why they often outperform CPUs by a significant margin when training large models or working with large datasets.

# %%
# Set this to False to disable GPU (CPU-only)
USE_GPU = True
if not USE_GPU:
    # Disable GPU by uninstalling tensorflow-metal
    # !pip3 uninstall -y tensorflow-metal
else:
    # Make sure GPU plugin is installed
    # !pip3 install -U tensorflow-metal
    
print("⚠️ Please RESTART the kernel after this cell before continuing.")
# Out:
# Requirement already satisfied: tensorflow-metal in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: six>=1.15.0 in /Users/epacuit/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow-metal) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# ⚠️ Please RESTART the kernel after this cell before continuing.

# %%
import tensorflow as tf

print("GPUs visible:", tf.config.list_physical_devices('GPU'))

# This prints every operation's device placement
tf.debugging.set_log_device_placement(True)
# Out:
# GPUs visible: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape((-1, 28, 28, 1)).astype("float32") / 255
x_test = x_test.reshape((-1, 28, 28, 1)).astype("float32") / 255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Input(shape=(28, 28, 1)),
    # layers.Conv2D(128, 3, activation='relu'),
    # layers.MaxPooling2D(),
    # layers.Conv2D(64, 3, activation='relu'),
    # layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.500538: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2025-05-06 06:33:42.500565: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 96.00 GB
# 2025-05-06 06:33:42.500569: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 36.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746527622.500580  659761 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1746527622.500601  659761 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-05-06 06:33:42.506926: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.506938: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.506941: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.509967: I tensorflow/core/common_runtime/placer.cc:162] x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.509975: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.509977: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.550447: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.550468: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.550470: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.552137: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.552144: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.552147: I tensorflow/core/common_runtime/placer.cc:162] FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.552150: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.553816: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.553826: I tensorflow/core/common_runtime/placer.cc:162] Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.553829: I tensorflow/core/common_runtime/placer.cc:162] y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.558190: I tensorflow/core/common_runtime/placer.cc:162] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.558202: I tensorflow/core/common_runtime/placer.cc:162] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.558205: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.560770: I tensorflow/core/common_runtime/placer.cc:162] seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.560779: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.560781: I tensorflow/core/common_runtime/placer.cc:162] key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.560784: I tensorflow/core/common_runtime/placer.cc:162] counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.562243: I tensorflow/core/common_runtime/placer.cc:162] shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.562249: I tensorflow/core/common_runtime/placer.cc:162] key: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.562255: I tensorflow/core/common_runtime/placer.cc:162] counter: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.562257: I tensorflow/core/common_runtime/placer.cc:162] alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.562260: I tensorflow/core/common_runtime/placer.cc:162] StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.562262: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.566385: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.566392: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.566397: I tensorflow/core/common_runtime/placer.cc:162] Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.566400: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.569724: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.569731: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.569735: I tensorflow/core/common_runtime/placer.cc:162] Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.569738: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.573046: I tensorflow/core/common_runtime/placer.cc:162] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.573055: I tensorflow/core/common_runtime/placer.cc:162] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.573059: I tensorflow/core/common_runtime/placer.cc:162] AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.573061: I tensorflow/core/common_runtime/placer.cc:162] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.576547: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.576556: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.577345: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.577354: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.577358: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.579633: I tensorflow/core/common_runtime/placer.cc:162] dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.579641: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.579645: I tensorflow/core/common_runtime/placer.cc:162] Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.579648: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.583378: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.583388: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.584010: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.584020: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.584024: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.599708: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.599720: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.600505: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.600514: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.600518: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.615123: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.615135: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.616007: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.616013: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.616017: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.629720: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.629737: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.630415: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.630421: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.630424: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.633814: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.633820: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.634522: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.634531: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.634535: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.641943: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.641953: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.642669: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.642674: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.642677: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.644390: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.644397: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.644994: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.645000: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.645004: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.649391: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.649398: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.651674: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.651681: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0

# %%
import time

start = time.time()
history = model.fit(x_train, y_train,
                    validation_split=0.1,
                    #batch_size=512,
                    batch_size=64,
                    epochs=5,
                    verbose=2)
end = time.time()

print(f"\nTraining time: {end - start:.2f} seconds")
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RangeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op FlatMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.659591: I tensorflow/core/common_runtime/placer.cc:162] start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.659597: I tensorflow/core/common_runtime/placer.cc:162] stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.659600: I tensorflow/core/common_runtime/placer.cc:162] step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.659603: I tensorflow/core/common_runtime/placer.cc:162] RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.659606: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.664946: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.664958: I tensorflow/core/common_runtime/placer.cc:162] MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.664960: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.666356: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.666366: I tensorflow/core/common_runtime/placer.cc:162] buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.666370: I tensorflow/core/common_runtime/placer.cc:162] PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.666374: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.673143: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.673154: I tensorflow/core/common_runtime/placer.cc:162] FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.673158: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.702969: I tensorflow/core/common_runtime/placer.cc:162] components_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.702980: I tensorflow/core/common_runtime/placer.cc:162] components_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.702985: I tensorflow/core/common_runtime/placer.cc:162] TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.702988: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ZipDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDatasetV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptionsDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/5
# Executing op AnonymousIteratorV3 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.717697: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.717707: I tensorflow/core/common_runtime/placer.cc:162] count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.717718: I tensorflow/core/common_runtime/placer.cc:162] RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.717721: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.719911: I tensorflow/core/common_runtime/placer.cc:162] input__datasets_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.719921: I tensorflow/core/common_runtime/placer.cc:162] input__datasets_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.719925: I tensorflow/core/common_runtime/placer.cc:162] ZipDataset: (ZipDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.719932: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.724284: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.724292: I tensorflow/core/common_runtime/placer.cc:162] num__parallel__calls: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.724296: I tensorflow/core/common_runtime/placer.cc:162] ParallelMapDatasetV2: (ParallelMapDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.724298: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725307: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725313: I tensorflow/core/common_runtime/placer.cc:162] OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725315: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725970: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725974: I tensorflow/core/common_runtime/placer.cc:162] OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.725977: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.726619: I tensorflow/core/common_runtime/placer.cc:162] input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.726626: I tensorflow/core/common_runtime/placer.cc:162] buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.726629: I tensorflow/core/common_runtime/placer.cc:162] PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.726631: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.727551: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.727558: I tensorflow/core/common_runtime/placer.cc:162] value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.727562: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.731798: I tensorflow/core/common_runtime/placer.cc:162] handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.731804: I tensorflow/core/common_runtime/placer.cc:162] AnonymousIteratorV3: (AnonymousIteratorV3): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.732396: I tensorflow/core/common_runtime/placer.cc:162] dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.732402: I tensorflow/core/common_runtime/placer.cc:162] iterator: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.732405: I tensorflow/core/common_runtime/placer.cc:162] MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733290: I tensorflow/core/common_runtime/placer.cc:162] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733300: I tensorflow/core/common_runtime/placer.cc:162] range: (Range): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733303: I tensorflow/core/common_runtime/placer.cc:162] RandomShuffle: (RandomShuffle): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733306: I tensorflow/core/common_runtime/placer.cc:162] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733309: I tensorflow/core/common_runtime/placer.cc:162] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733312: I tensorflow/core/common_runtime/placer.cc:162] range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733315: I tensorflow/core/common_runtime/placer.cc:162] range/limit: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.733318: I tensorflow/core/common_runtime/placer.cc:162] range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736099: I tensorflow/core/common_runtime/placer.cc:162] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736106: I tensorflow/core/common_runtime/placer.cc:162] Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736110: I tensorflow/core/common_runtime/placer.cc:162] Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736113: I tensorflow/core/common_runtime/placer.cc:162] TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736115: I tensorflow/core/common_runtime/placer.cc:162] Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736119: I tensorflow/core/common_runtime/placer.cc:162] TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736122: I tensorflow/core/common_runtime/placer.cc:162] ConcatenateDataset: (ConcatenateDataset): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736124: I tensorflow/core/common_runtime/placer.cc:162] NoOp: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736128: I tensorflow/core/common_runtime/placer.cc:162] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736130: I tensorflow/core/common_runtime/placer.cc:162] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736133: I tensorflow/core/common_runtime/placer.cc:162] Slice/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736136: I tensorflow/core/common_runtime/placer.cc:162] Slice/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736138: I tensorflow/core/common_runtime/placer.cc:162] Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736141: I tensorflow/core/common_runtime/placer.cc:162] Slice_1/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.736143: I tensorflow/core/common_runtime/placer.cc:162] Slice_1/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739225: I tensorflow/core/common_runtime/placer.cc:162] args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739238: I tensorflow/core/common_runtime/placer.cc:162] args_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739240: I tensorflow/core/common_runtime/placer.cc:162] args_2: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739243: I tensorflow/core/common_runtime/placer.cc:162] GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739247: I tensorflow/core/common_runtime/placer.cc:162] GatherV2_1: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739249: I tensorflow/core/common_runtime/placer.cc:162] Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739252: I tensorflow/core/common_runtime/placer.cc:162] Identity_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739254: I tensorflow/core/common_runtime/placer.cc:162] identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739256: I tensorflow/core/common_runtime/placer.cc:162] identity_1_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739259: I tensorflow/core/common_runtime/placer.cc:162] GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.739261: I tensorflow/core/common_runtime/placer.cc:162] GatherV2_1/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-05-06 06:33:42.770326: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.770338: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.776597: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.776610: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.784129: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.784139: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.790847: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.790880: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.797240: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.797251: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.803528: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.803544: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.810021: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.810032: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.815060: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.815067: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.819856: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.819865: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.825654: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.825665: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.831056: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.831066: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.836304: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.836315: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.875621: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.875637: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.880206: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.880213: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.906531: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.906543: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.906546: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.908910: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.908924: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.908927: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.910892: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.910903: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.910906: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.912852: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.912858: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.912861: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.914747: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.914754: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.914757: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.916494: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.916500: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.916503: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_DeviceArg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FloorMod: (FloorMod): /job:localhost/replica:0/task:0/device:CPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Cast: (Cast): /job:localhost/replica:0/task:0/device:GPU:0
# y_RetVal: (_DeviceRetval): /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# seed: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomGetKeyCounter: (StatelessRandomGetKeyCounter): /job:localhost/replica:0/task:0/device:CPU:0
# key_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# counter_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# key: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# counter: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# alg: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# StatelessRandomUniformV2: (StatelessRandomUniformV2): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dims: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Fill: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# start: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# stop: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# step: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RangeDataset: (RangeDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MapDataset: (MapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# FlatMapDataset: (FlatMapDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# components_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# components_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# count: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# RepeatDataset: (RepeatDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# input__datasets_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ZipDataset: (ZipDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# num__parallel__calls: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# ParallelMapDatasetV2: (ParallelMapDatasetV2): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# OptionsDataset: (OptionsDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# input__dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# buffer__size: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# PrefetchDataset: (PrefetchDataset): /job:localhost/replica:0/task:0/device:CPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# value: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# handle_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# AnonymousIteratorV3: (AnonymousIteratorV3): /job:localhost/replica:0/task:0/device:CPU:0
# dataset: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# iterator: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# MakeIterator: (MakeIterator): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# range: (Range): /job:localhost/replica:0/task:0/device:CPU:0
# RandomShuffle: (RandomShuffle): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# range/limit: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# Slice: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# Reshape: (Reshape): /job:localhost/replica:0/task:0/device:CPU:0
# TensorSliceDataset: (TensorSliceDataset): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1: (Slice): /job:localhost/replica:0/task:0/device:CPU:0
# TensorDataset: (TensorDataset): /job:localhost/replica:0/task:0/device:CPU:0
# ConcatenateDataset: (ConcatenateDataset): /job:localhost/replica:0/task:0/device:CPU:0
# NoOp: (NoOp): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# Slice/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1/begin: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# Slice_1/size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# args_0: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# args_1: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# args_2: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2_1: (GatherV2): /job:localhost/replica:0/task:0/device:CPU:0
# Identity: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# Identity_1: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# identity_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# identity_1_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# GatherV2_1/axis: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# values_0: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_1: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_2: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_3: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_4: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_5: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_6: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_7: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_8: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_9: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_10: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_11: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_12: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# values_13: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Pack: (PExecuting op Pack in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_initialize_variables_912 in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.918302: I tensorflow/core/common_runtime/placer.cc:162] resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.918315: I tensorflow/core/common_runtime/placer.cc:162] VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.918318: I tensorflow/core/common_runtime/placer.cc:162] is__initialized_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920317: I tensorflow/core/common_runtime/placer.cc:162] values_0: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920324: I tensorflow/core/common_runtime/placer.cc:162] values_1: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920326: I tensorflow/core/common_runtime/placer.cc:162] values_2: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920328: I tensorflow/core/common_runtime/placer.cc:162] values_3: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920330: I tensorflow/core/common_runtime/placer.cc:162] values_4: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920332: I tensorflow/core/common_runtime/placer.cc:162] values_5: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920334: I tensorflow/core/common_runtime/placer.cc:162] values_6: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920335: I tensorflow/core/common_runtime/placer.cc:162] values_7: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920337: I tensorflow/core/common_runtime/placer.cc:162] values_8: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920339: I tensorflow/core/common_runtime/placer.cc:162] values_9: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920341: I tensorflow/core/common_runtime/placer.cc:162] values_10: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920343: I tensorflow/core/common_runtime/placer.cc:162] values_11: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920345: I tensorflow/core/common_runtime/placer.cc:162] values_12: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920347: I tensorflow/core/common_runtime/placer.cc:162] values_13: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920380: I tensorflow/core/common_runtime/placer.cc:162] Pack: (Pack): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.920384: I tensorflow/core/common_runtime/placer.cc:162] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932342: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932357: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_1_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932365: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_2_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932368: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_3_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932369: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_4_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932371: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_5_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932373: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_6_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932375: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_7_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932377: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_8_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932378: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_9_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932380: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_10_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932382: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_11_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932384: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_12_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932386: I tensorflow/core/common_runtime/placer.cc:162] assignvariableop_13_resource: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932392: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_dense_kernel_momentum/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932395: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_dense_kernel_velocity/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932397: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932400: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_1: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932402: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_2: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932404: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_3: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932407: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_4: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932409: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_5: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932412: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_6: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932414: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_7: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932416: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_8: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932418: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_9: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932420: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_10: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932422: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_11: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932425: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_12: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932427: I tensorflow/core/common_runtime/placer.cc:162] AssignVariableOp_13: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932429: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_kernel_momentum/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932432: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_kernel_velocity/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932435: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_bias_momentum/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-06 06:33:42.932437: I tensorflow/core/common_runtime/placer.cc:162] adam/sequential_conv2d_bias_velocity/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# ...
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalHasValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op OptionalGetValue in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_multi_step_on_iterator_1401 in device /job:localhost/replica:0/task:0/device:GPU:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import time
#       3 start = time.time()
# ----> 4 history = model.fit(x_train, y_train,
#       5                     validation_split=0.1,
#       6                     #batch_size=512,
#       7                     batch_size=64,
#       8                     epochs=5,
#       9                     verbose=2)
#      10 end = time.time()
#      12 print(f"\nTraining time: {end - start:.2f} seconds")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Version 1 (with a larger CNN and batch size), for 5 Epochs:
# * Training on the CPU: 61.05 seconds
# * Training on the GPU: 15.04 seconds
#
# Version 2 (with a smaller CNN and batch size), for 5 Epochs:
# * Training on the CPU: 18.71 seconds
# * Training on the GPU: 57.40 seconds
#
# The conclusion is that the GPU is *not always* faster than the CPU.  There is a significant amount of overhead in transferring data to and from the GPU, and for smaller models or smaller batch sizes, this overhead can outweigh the benefits of parallel processing.

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()
